# %% [markdown]
# # Description:
#
# Airfares and passengers for U.S. Domestic Routes for 4th Quarter of 2002.
#
# # Variables/Columns
#
# City1 1-3
#
# City2 5-7
#
# Average Fare 11-17
#
# Distance 20-23
#
# Average weekly passengers 26-33
#
# market leading airline 36-37
#
# market share 40-45
#
# Average fare 48-54
#
# Low price airline 57-58
#
# market share 61-66
#
# price 69-75
#
# # Source:
#
# U.S. Department of Transportation

# %%
# Importing Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# reading source file

df=pd.read_csv("C:/Users/pavpr/Downloads/Airline Fare Analysis.csv")
df
# Out:
#      Unnamed: 0 City1 City2  Average Flight Fare  Distance  \
# 0             0   CAK   MCO               122.47       860
# 1             1   ALB   ATL               214.42       852
# 2             2   ALB   BWI                69.40       288
# 3             3   ALB   ORD               158.13       723
# 4             4   ALB   FLL               135.17      1204
# ..          ...   ...   ...                  ...       ...
# 994         994   SYR   TPA               136.16      1104
# 995         995   TLH   TPA                83.28       200
# 996         996   TPA   IAD               159.97       814
# 997         997   TPA   PBI                73.57       174
# 998         998   IAD   PBI               126.67       859
#
#      Average Weekly Passengers Market Leading Airline (MLA)  Market Share MLA  \
# 0                       276.84                           FL             75.10
# 1                       215.76                           DL             78.89
# ...

# %%
# dropping 'Unnamed' Column.

df=df.drop(['Unnamed: 0'],axis=1)

# %%
df.head()
# Out:
#   City1 City2  Average Flight Fare  Distance  Average Weekly Passengers  \
# 0   CAK   MCO               122.47       860                     276.84
# 1   ALB   ATL               214.42       852                     215.76
# 2   ALB   BWI                69.40       288                     606.84
# 3   ALB   ORD               158.13       723                     313.04
# 4   ALB   FLL               135.17      1204                     199.02
#
#   Market Leading Airline (MLA)  Market Share MLA  Average MLA Fare  \
# 0                           FL             75.10            123.09
# 1                           DL             78.89            223.98
# 2                           WN             96.97             68.86
# 3                           UA             39.79            161.36
# 4                           WN             40.68            137.97
#
#   Low Price Airline (LPA)  Market Share LPA  Average LPA Fare
# 0                      DL             17.23            118.94
# ...

# %%
# Creating a duplicate copy for data manupulation without disturbing the original dataset and reading the dataset.

df1=df.copy(deep=True)
df1.head()
# Out:
#   City1 City2  Average Flight Fare  Distance  Average Weekly Passengers  \
# 0   CAK   MCO               122.47       860                     276.84
# 1   ALB   ATL               214.42       852                     215.76
# 2   ALB   BWI                69.40       288                     606.84
# 3   ALB   ORD               158.13       723                     313.04
# 4   ALB   FLL               135.17      1204                     199.02
#
#   Market Leading Airline (MLA)  Market Share MLA  Average MLA Fare  \
# 0                           FL             75.10            123.09
# 1                           DL             78.89            223.98
# 2                           WN             96.97             68.86
# 3                           UA             39.79            161.36
# 4                           WN             40.68            137.97
#
#   Low Price Airline (LPA)  Market Share LPA  Average LPA Fare
# 0                      DL             17.23            118.94
# ...

# %%
# getting total number of rows and column in the dataframe

df1.shape
# Out:
# (999, 11)

# %%
# dealing with missing data
# to check for NaN values
# True for NaN values
# NaN not a number

df1.isnull().sum()
# Out:
# City1                           0
# City2                           0
# Average Flight Fare             0
# Distance                        0
# Average Weekly Passengers       0
# Market Leading Airline (MLA)    0
# Market Share MLA                0
# Average MLA Fare                0
# Low Price Airline (LPA)         0
# Market Share LPA                0
# Average LPA Fare                0
# dtype: int64

# %% [markdown]
# there are no null values

# %%
# number of axis or array dimensions

df1.ndim
# Out:
# 2

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=999, step=1)

# %%
# extracting all the columns

df1.columns
# Out:
# Index(['City1', 'City2', 'Average Flight Fare', 'Distance',
#        'Average Weekly Passengers', 'Market Leading Airline (MLA)',
#        'Market Share MLA', 'Average MLA Fare', 'Low Price Airline (LPA)',
#        'Market Share LPA', 'Average LPA Fare'],
#       dtype='object')

# %%
# to find duplicates

print(df1.duplicated().sum())
# Out:
# 0

# %% [markdown]
# There are no duplicates

# %%
# Concise summary

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   City1                         999 non-null    object
#  1   City2                         999 non-null    object
#  2   Average Flight Fare           999 non-null    float64
#  3   Distance                      999 non-null    int64
#  4   Average Weekly Passengers     999 non-null    float64
#  5   Market Leading Airline (MLA)  999 non-null    object
#  6   Market Share MLA              999 non-null    float64
#  7   Average MLA Fare              999 non-null    float64
#  8   Low Price Airline (LPA)       999 non-null    object
#  9   Market Share LPA              999 non-null    float64
#  10  Average LPA Fare              999 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 86.0+ KB

# %%
# Checking data type of each colunm to check if any type needs to be changed
df1.dtypes
# Out:
# City1                            object
# City2                            object
# Average Flight Fare             float64
# Distance                          int64
# Average Weekly Passengers       float64
# Market Leading Airline (MLA)     object
# Market Share MLA                float64
# Average MLA Fare                float64
# Low Price Airline (LPA)          object
# Market Share LPA                float64
# Average LPA Fare                float64
# dtype: object

# %%
# 5 point summary

df1.describe()
# Out:
#        Average Flight Fare     Distance  Average Weekly Passengers  \
# count           999.000000   999.000000                 999.000000
# mean            163.424374  1057.502503                 672.527107
# std              55.371544   643.307320                 766.863056
# min              50.520000   108.000000                 181.410000
# 25%             126.025000   554.000000                 257.115000
# 50%             161.360000   919.000000                 404.780000
# 75%             197.435000  1455.000000                 770.265000
# max             401.230000  2724.000000                8950.760000
#
#        Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# count        999.000000        999.000000        999.000000        999.000000
# mean          60.118519        166.703233         34.515806        143.225285
# std           19.374859         62.666775         27.087067         47.241860
# ...

# %%
# Used to show the strength of association between two variables
# range -1 to 1

df1.corr()
# Out:
#                            Average Flight Fare  Distance  \
# Average Flight Fare                   1.000000  0.586869
# Distance                              0.586869  1.000000
# Average Weekly Passengers            -0.126517 -0.090433
# Market Share MLA                     -0.233805 -0.531229
# Average MLA Fare                      0.981448  0.563765
# Market Share LPA                     -0.458072 -0.367190
# Average LPA Fare                      0.866348  0.583011
#
#                            Average Weekly Passengers  Market Share MLA  \
# Average Flight Fare                        -0.126517         -0.233805
# Distance                                   -0.090433         -0.531229
# Average Weekly Passengers                   1.000000         -0.067450
# Market Share MLA                           -0.067450          1.000000
# Average MLA Fare                           -0.101279         -0.220456
# Market Share LPA                            0.034699          0.306454
# ...

# %%
# Used to show pairwise relationships in a dataset

sns.pairplot(df1)

# %% [markdown]
# # Bivariant Analysis

# %%
sns.scatterplot(data=df1, x="Distance", y="Average Flight Fare")
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Average Flight Fare'>

# %%
sns.scatterplot(data=df1, x="Average Weekly Passengers", y="Average Flight Fare")
# Out:
# <AxesSubplot:xlabel='Average Weekly Passengers', ylabel='Average Flight Fare'>

# %% [markdown]
# # Univariant Analysis

# %%
sns.boxplot(x="Average Weekly Passengers",data= df1, hue=None)
# Out:
# <AxesSubplot:xlabel='Average Weekly Passengers'>

# %%
sns.boxplot(x="Distance",data= df1, hue=None)
# Out:
# <AxesSubplot:xlabel='Distance'>

# %%
sns.boxplot(x="Average Flight Fare",data= df1, hue=None)
# Out:
# <AxesSubplot:xlabel='Average Flight Fare'>

# %%
# Box-whisker plot & Histogram on the same window.

f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios":(.15,.85)})

sns.boxplot(df1["Average Flight Fare"],ax=ax_box)
sns.distplot(df1["Average Flight Fare"],ax=ax_hist,kde=False)
# Out:
# <AxesSubplot:xlabel='Average Flight Fare'>

# %%
sns.boxplot(x="Distance",y="Average Flight Fare",hue=None, data=df1)
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Average Flight Fare'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df1, y_vars='Average Flight Fare',x_vars=["Distance", "Average Weekly Passengers",
                                                       'Market Share MLA', 'Average MLA Fare','Market Share LPA','Average LPA Fare'
                                                        ])
plt.show()

# %%
# Dropping cities and Flight Name colunm as these are not actionable

df1.drop(['City1'], axis = 1, inplace = True)
df1.drop(['City2'], axis = 1, inplace = True)
df1.drop(['Market Leading Airline (MLA)'], axis = 1, inplace = True)
df1.drop(['Low Price Airline (LPA)'], axis = 1, inplace = True)

# %%
df1.head()
# Out:
#    Average Flight Fare  Distance  Average Weekly Passengers  Market Share MLA  \
# 0               122.47       860                     276.84             75.10
# 1               214.42       852                     215.76             78.89
# 2                69.40       288                     606.84             96.97
# 3               158.13       723                     313.04             39.79
# 4               135.17      1204                     199.02             40.68
#
#    Average MLA Fare  Market Share LPA  Average LPA Fare
# 0            123.09             17.23            118.94
# 1            223.98              2.77            167.12
# 2             68.86             96.97             68.86
# 3            161.36             15.34            145.42
# 4            137.97             17.09            127.69

# %%
df1.shape
# Out:
# (999, 7)

# %% [markdown]
# # assigning the features and target variable into x and y in train data

# %%
x=df1 
y=df1.pop("Average Flight Fare")

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25,random_state=9)

# %% [markdown]
# # Rescaling the Features

# %%
# StandardScaler follows Standard Normal Distribution (SND).
# Therefore, it makes mean = 0 and scales the data to unit variance. 

from sklearn.preprocessing import StandardScaler
st_x=StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.transform(x_test)

# %% [markdown]
# # Fitting the model

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', lm.coef_)
# Out:
# Coefficients:  [ 1.02330458 -1.03584905  0.98450804 44.90346059 -1.53697702  9.91507849]

# %%
#make prediction
pred=lm.predict(x_test)

# %%
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate evaluation metrics
mae = mean_absolute_error(y_test,pred)
mse = mean_squared_error(y_test,pred)
r_squared = r2_score(y_test,pred)
rmse = np.sqrt(mse)
 
# Print the evaluation metrics
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R²):", r_squared)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 6.196556294335136
# Mean Squared Error (MSE): 74.24593744053324
# R-squared (R²): 0.9756439232266128
# Root Mean Squared Error (RMSE): 8.61660823297272

# %% [markdown]
# # Residual Analysis

# %%
y_train_price = lm.predict(x_train)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# <!--  Error Terms are normally distributed - hence prediction can be made -->

# %% [markdown]
# #  Making prediction using final model

# %%
y_pred = lm.predict(x_test)

# %%
# Plotting y_test and y_pred to understand the spread

plt.scatter(y_test,pred)

# %%
from sklearn import metrics
metrics.explained_variance_score(y_test,pred)
# Out:
# 0.975692895149897

# %% [markdown]
# Model is able to explain 97% of variance in test data
